# %%
from modelscope import snapshot_download
local_dir="model"
model_dir = snapshot_download('opendatalab/PDF-Extract-Kit',local_dir=local_dir)
# Out:
# ...
# 2025-08-25 23:48:23,654 - modelscope - INFO - Got 63 files, start to download ...
# Processing 63 items:   0%|          | 0.00/63.0 [00:00<?, ?it/s]
# ...
# 2025-08-26 00:12:04,948 - modelscope - INFO - Download model 'opendatalab/PDF-Extract-Kit' successfully.
